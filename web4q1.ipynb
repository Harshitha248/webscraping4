# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of most-viewed YouTube videos - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"0af12be6-4f7a-43f6-b4ad-16002072a11b","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_most-viewed_YouTube_videos","wgTitle":"List of most-viewed YouTube videos","wgCurRevisionId":1020592316,"wgRevisionId":1020592316,"wgArticleId":37743450,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pages using the EasyTimeline extension","Articles containing potentially dated statements from
# ...

# %%
soup=BeautifulSoup(page.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of most-viewed YouTube videos - Wikipedia</title>
# ...

# %%
name=soup.find_all('tr')

# %%
name[3:4]
# Out:
# [<tr>
#  <td align="center">1.</td>
#  <td>"<a class="mw-redirect" href="/wiki/Baby_Shark_Dance" title="Baby Shark Dance">Baby Shark Dance</a>"<sup class="reference" id="cite_ref-Baby_Shark_Dance_23-0"><a href="#cite_note-Baby_Shark_Dance-23">[22]</a></sup></td>
#  <td><a href="/wiki/Pinkfong" title="Pinkfong">Pinkfong Kids' Songs &amp; Stories</a></td>
#  <td align="center">8.44</td>
#  <td align="right">June 17, 2016</td>
#  <td align="center"><sup class="reference" id="cite_ref-25"><a href="#cite_note-25">[B]</a></sup>
#  </td></tr>]

# %%
name[4:5]
# Out:
# [<tr>
#  <td align="center">2.</td>
#  <td>"<a href="/wiki/Despacito#Music_video" title="Despacito">Despacito</a>"<sup class="reference" id="cite_ref-Despacito_26-0"><a href="#cite_note-Despacito-26">[24]</a></sup></td>
#  <td><a href="/wiki/Luis_Fonsi" title="Luis Fonsi">Luis Fonsi</a></td>
#  <td align="center">7.32</td>
#  <td align="right">January 12, 2017</td>
#  <td align="center"><sup class="reference" id="cite_ref-27"><a href="#cite_note-27">[C]</a></sup>
#  </td></tr>]

# %%
name[5:6]
# Out:
# [<tr>
#  <td align="center">3.</td>
#  <td>"<a href="/wiki/Shape_of_You#Music_video" title="Shape of You">Shape of You</a>"<sup class="reference" id="cite_ref-Shape_of_You_28-0"><a href="#cite_note-Shape_of_You-28">[25]</a></sup></td>
#  <td><a href="/wiki/Ed_Sheeran" title="Ed Sheeran">Ed Sheeran</a></td>
#  <td align="center">5.29</td>
#  <td align="right">January 30, 2017</td>
#  <td align="center"><sup class="reference" id="cite_ref-29"><a href="#cite_note-29">[D]</a></sup>
#  </td></tr>]

# %%
name[6:7]
# Out:
# [<tr>
#  <td align="center">4.</td>
#  <td>"<a href="/wiki/Johny_Johny_Yes_Papa#Music_videos" title="Johny Johny Yes Papa">Johny Johny Yes Papa</a>"<sup class="reference" id="cite_ref-Johny_Johny_Yes_Papa_30-0"><a href="#cite_note-Johny_Johny_Yes_Papa-30">[26]</a></sup></td>
#  <td>LooLoo Kids</td>
#  <td align="center">5.24</td>
#  <td align="right">October 8, 2016</td>
#  <td align="center"><sup class="reference" id="cite_ref-31"><a href="#cite_note-31">[E]</a></sup>
#  </td></tr>]

# %%
name[7:8]
# Out:
# [<tr>
#  <td align="center">5.</td>
#  <td>"<a href="/wiki/See_You_Again#Music_video" title="See You Again">See You Again</a>"<sup class="reference" id="cite_ref-See_You_Again_32-0"><a href="#cite_note-See_You_Again-32">[27]</a></sup></td>
#  <td><a href="/wiki/Wiz_Khalifa" title="Wiz Khalifa">Wiz Khalifa</a></td>
#  <td align="center">5.08</td>
#  <td align="right">April 6, 2015</td>
#  <td align="center"><sup class="reference" id="cite_ref-35"><a href="#cite_note-35">[F]</a></sup>
#  </td></tr>]

# %%
name[8:9]
# Out:
# [<tr>
#  <td align="center">6.</td>
#  <td>"<i><a href="/wiki/Masha_and_the_Bear" title="Masha and the Bear">Masha and the Bear</a></i> – Recipe for Disaster"<sup class="reference" id="cite_ref-Masha_and_the_Bear_36-0"><a href="#cite_note-Masha_and_the_Bear-36">[30]</a></sup></td>
#  <td>Get Movies</td>
#  <td align="center">4.43</td>
#  <td align="right">January 31, 2012</td>
#  <td align="center"><sup class="reference" id="cite_ref-37"><a href="#cite_note-37">[G]</a></sup>
#  </td></tr>]

# %%
name[9:10]
# Out:
# [<tr>
#  <td align="center">7.</td>
#  <td>"<a href="/wiki/Uptown_Funk#Music_video" title="Uptown Funk">Uptown Funk</a>"<sup class="reference" id="cite_ref-Uptown_Funk_38-0"><a href="#cite_note-Uptown_Funk-38">[31]</a></sup></td>
#  <td><a href="/wiki/Mark_Ronson" title="Mark Ronson">Mark Ronson</a></td>
#  <td align="center">4.16</td>
#  <td align="right">November 19, 2014</td>
#  <td align="center"><sup class="reference" id="cite_ref-39"><a href="#cite_note-39">[H]</a></sup>
#  </td></tr>]

# %%
name[10:11]
# Out:
# [<tr>
#  <td align="center">8.</td>
#  <td>"<a href="/wiki/Gangnam_Style_(music_video)" title="Gangnam Style (music video)">Gangnam Style</a>"<sup class="reference" id="cite_ref-Gangnam_Style_40-0"><a href="#cite_note-Gangnam_Style-40">[32]</a></sup></td>
#  <td><a href="/wiki/Psy" title="Psy">Psy</a></td>
#  <td align="center">4.05</td>
#  <td align="right">July 15, 2012</td>
#  <td align="center"><sup class="reference" id="cite_ref-42"><a href="#cite_note-42">[I]</a></sup>
#  </td></tr>]

# %%
name[11:12]
# Out:
# [<tr>
#  <td align="center">9.</td>
#  <td>"Learning Colors – Colorful Eggs on a Farm"<sup class="reference" id="cite_ref-Eggs_43-0"><a href="#cite_note-Eggs-43">[34]</a></sup></td>
#  <td>Miroshka TV</td>
#  <td align="center">3.97</td>
#  <td align="right">February 27, 2018</td>
#  <td>
#  </td></tr>]

# %%
name[12:13]
# Out:
# [<tr>
#  <td align="center">10.</td>
#  <td>"Bath Song"<sup class="reference" id="cite_ref-Bath_Song_44-0"><a href="#cite_note-Bath_Song-44">[35]</a></sup></td>
#  <td><a class="mw-redirect" href="/wiki/Cocomelon_%E2%80%93_Nursery_Rhymes" title="Cocomelon – Nursery Rhymes">Cocomelon – Nursery Rhymes</a></td>
#  <td align="center">3.95</td>
#  <td align="right">May 2, 2018</td>
#  <td>
#  </td></tr>]

# %%
name[13:14]
# Out:
# [<tr>
#  <td align="center">11.</td>
#  <td>"Phonics Song with Two Words"<sup class="reference" id="cite_ref-Phonics_Song_45-0"><a href="#cite_note-Phonics_Song-45">[36]</a></sup></td>
#  <td><a href="/wiki/ChuChu_TV" title="ChuChu TV">ChuChu TV</a></td>
#  <td align="center">3.78</td>
#  <td align="right">March 6, 2014</td>
#  <td>
#  </td></tr>]

# %%
name= soup.find_all('td')

# %%
name[5]
# Out:
# <td>"<a class="mw-redirect" href="/wiki/Baby_Shark_Dance" title="Baby Shark Dance">Baby Shark Dance</a>"<sup class="reference" id="cite_ref-Baby_Shark_Dance_23-0"><a href="#cite_note-Baby_Shark_Dance-23">[22]</a></sup></td>

# %%
name[11]
# Out:
# <td>"<a href="/wiki/Despacito#Music_video" title="Despacito">Despacito</a>"<sup class="reference" id="cite_ref-Despacito_26-0"><a href="#cite_note-Despacito-26">[24]</a></sup></td>

# %%
name[17]
# Out:
# <td>"<a href="/wiki/Shape_of_You#Music_video" title="Shape of You">Shape of You</a>"<sup class="reference" id="cite_ref-Shape_of_You_28-0"><a href="#cite_note-Shape_of_You-28">[25]</a></sup></td>

# %%
name[23]
# Out:
# <td>"<a href="/wiki/Johny_Johny_Yes_Papa#Music_videos" title="Johny Johny Yes Papa">Johny Johny Yes Papa</a>"<sup class="reference" id="cite_ref-Johny_Johny_Yes_Papa_30-0"><a href="#cite_note-Johny_Johny_Yes_Papa-30">[26]</a></sup></td>

# %%
name[29]
# Out:
# <td>"<a href="/wiki/See_You_Again#Music_video" title="See You Again">See You Again</a>"<sup class="reference" id="cite_ref-See_You_Again_32-0"><a href="#cite_note-See_You_Again-32">[27]</a></sup></td>

# %%
name[35]
# Out:
# <td>"<i><a href="/wiki/Masha_and_the_Bear" title="Masha and the Bear">Masha and the Bear</a></i> – Recipe for Disaster"<sup class="reference" id="cite_ref-Masha_and_the_Bear_36-0"><a href="#cite_note-Masha_and_the_Bear-36">[30]</a></sup></td>

# %%
name[41]
# Out:
# <td>"<a href="/wiki/Uptown_Funk#Music_video" title="Uptown Funk">Uptown Funk</a>"<sup class="reference" id="cite_ref-Uptown_Funk_38-0"><a href="#cite_note-Uptown_Funk-38">[31]</a></sup></td>

# %%
name[47]
# Out:
# <td>"<a href="/wiki/Gangnam_Style_(music_video)" title="Gangnam Style (music video)">Gangnam Style</a>"<sup class="reference" id="cite_ref-Gangnam_Style_40-0"><a href="#cite_note-Gangnam_Style-40">[32]</a></sup></td>

# %%
names=[]
for i in range(0,len(name)):
    names.append(name[i].get_text())

# %%
names
# Out:
# ['',
#  'This article needs additional citations for verification. Please help improve this article by adding citations to reliable sources. Unsourced material may be challenged and removed.Find sources:\xa0"List of most-viewed YouTube videos"\xa0–\xa0news\xa0· newspapers\xa0· books\xa0· scholar\xa0· JSTOR (March 2021) (Learn how and when to remove this template message)',
#  '',
#  'This section possibly contains original research. Please improve it by verifying the claims made and adding inline citations. Statements consisting only of original research should be removed. (March 2021) (Learn how and when to remove this template message)',
#  '1.',
#  '"Baby Shark Dance"[22]',
#  "Pinkfong Kids' Songs & Stories",
#  '8.44',
#  'June 17, 2016',
#  '[B]\n',
#  '2.',
#  '"Despacito"[24]',
#  'Luis Fonsi',
#  '7.32',
#  'January 12, 2017',
#  '[C]\n',
#  '3.',
#  '"Shape of You"[25]',
#  'Ed Sheeran',
#  '5.29',
#  'January 30, 2017',
#  '[D]\n',
#  '4.',
# ...

# %%
names.pop(1)
# Out:
# 'This article needs additional citations for verification. Please help improve this article by adding citations to reliable sources. Unsourced material may be challenged and removed.Find sources:\xa0"List of most-viewed YouTube videos"\xa0–\xa0news\xa0· newspapers\xa0· books\xa0· scholar\xa0· JSTOR (March 2021) (Learn how and when to remove this template message)'

# %%
names
# Out:
# ['',
#  '',
#  'This section possibly contains original research. Please improve it by verifying the claims made and adding inline citations. Statements consisting only of original research should be removed. (March 2021) (Learn how and when to remove this template message)',
#  '1.',
#  '"Baby Shark Dance"[22]',
#  "Pinkfong Kids' Songs & Stories",
#  '8.44',
#  'June 17, 2016',
#  '[B]\n',
#  '2.',
#  '"Despacito"[24]',
#  'Luis Fonsi',
#  '7.32',
#  'January 12, 2017',
#  '[C]\n',
#  '3.',
#  '"Shape of You"[25]',
#  'Ed Sheeran',
#  '5.29',
#  'January 30, 2017',
#  '[D]\n',
#  '4.',
#  '"Johny Johny Yes Papa"[26]',
#  'LooLoo Kids',
#  '5.24',
#  'October 8, 2016',
#  '[E]\n',
#  '5.',
#  '"See You Again"[27]',
#  'Wiz Khalifa',
#  '5.08',
#  'April 6, 2015',
#  '[F]\n',
#  '6.',
#  '"Masha and the Bear – Recipe for Disaster"[30]',
#  'Get Movies',
#  '4.43',
#  'January 31, 2012',
#  '[G]\n',
#  '7.',
#  '"Uptown Funk"[31]',
#  'Mark Ronson',
#  '4.16',
#  'November 19, 2014',
# ...

# %%
names.pop(1)
# Out:
# ''

# %%
names.pop(1)
# Out:
# 'This section possibly contains original research. Please improve it by verifying the claims made and adding inline citations. Statements consisting only of original research should be removed. (March 2021) (Learn how and when to remove this template message)'

# %%
names.pop(1)
# Out:
# '1.'

# %%
names.pop(0)
# Out:
# ''

# %%
names.pop(1)
# Out:
# "Pinkfong Kids' Songs & Stories"

# %%
names.pop(1)
# Out:
# '8.44'

# %%
names.pop(1)
# Out:
# 'June 17, 2016'

# %%
names.pop(1)
# Out:
# '[B]\n'

# %%
names.pop(1)
# Out:
# '2.'

# %%
names.pop(3)
# Out:
# '7.32'

# %%
names.pop(3)
# Out:
# 'January 12, 2017'

# %%
names.pop(3)
# Out:
# '[C]\n'

# %%
names.pop(3)
# Out:
# '3.'

# %%
names.pop(4)
# Out:
# 'Ed Sheeran'

# %%
names.pop(5)
# Out:
# 'January 30, 2017'

# %%
names.pop(4)
# Out:
# '5.29'

# %%
names.pop(4)
# Out:
# '[D]\n'

# %%
names.pop(4)
# Out:
# '4.'

# %%
names.pop(5)
# Out:
# 'LooLoo Kids'

# %%
names.pop(5)
# Out:
# '5.24'

# %%
names.pop(5)
# Out:
# 'October 8, 2016'

# %%
names.pop(5)
# Out:
# '[E]\n'

# %%
names.pop(5)
# Out:
# '5.'

# %%
names.pop(6)
# Out:
# 'Wiz Khalifa'

# %%
names.pop(6)
# Out:
# '5.08'

# %%
names.pop(6)
# Out:
# 'April 6, 2015'

# %%
names.pop(6)
# Out:
# '[F]\n'

# %%
names.pop(6)
# Out:
# '6.'

# %%
names.pop(7)
# Out:
# 'Get Movies'

# %%
names.pop(7)
# Out:
# '4.43'

# %%
names.pop(7)
# Out:
# 'January 31, 2012'

# %%
names.pop(7)
# Out:
# '[G]\n'

# %%
names.pop(7)
# Out:
# '7.'

# %%
names.pop(2)
# Out:
# 'Luis Fonsi'

# %%
names.pop(8)
# Out:
# '4.16'

# %%
names.pop(8)
# Out:
# 'November 19, 2014'

# %%
names.pop(8)
# Out:
# '[H]\n'

# %%
names.pop(7)
# Out:
# 'Mark Ronson'

# %%
names.pop(7)
# Out:
# '8.'

# %%
names.pop(9)
# Out:
# '4.05'

# %%
names.pop(9)
# Out:
# 'July 15, 2012'

# %%
names.pop(9)
# Out:
# '[I]\n'

# %%
names.pop(9)
# Out:
# '9.'

# %%
names.pop(8)
# Out:
# 'Psy'

# %%
names.pop(9)
# Out:
# 'Miroshka TV'

# %%
names.pop(9)
# Out:
# '3.97'

# %%
names.pop(9)
# Out:
# 'February 27, 2018'

# %%
names.pop(9)
# Out:
# '\n'

# %%
names.pop(9)
# Out:
# '10.'

# %%
names.pop(10)
# Out:
# 'Cocomelon – Nursery Rhymes'

# %%
names.pop(10)
# Out:
# '3.95'

# %%
names.pop(10)
# Out:
# 'May 2, 2018'

# %%
names.pop(10)
# Out:
# '\n'

# %%
names.pop(10)
# Out:
# '11.'

# %%
names.pop(11)
# Out:
# 'ChuChu TV'

# %%
names.pop(11)
# Out:
# '3.78'

# %%
names.pop(11)
# Out:
# 'March 6, 2014'

# %%
names.pop(11)
# Out:
# '\n'

# %%
names.pop(11)
# Out:
# '12.'

# %%
names.pop(12)
# Out:
# 'Maroon 5'

# %%
names.pop(12)
# Out:
# '3.45'

# %%
names.pop(12)
# Out:
# 'January 14, 2015'

# %%
names.pop(12)
# Out:
# '\n'

# %%
names.pop(12)
# Out:
# '13.'

# %%
names.pop(13)
# Out:
# 'Justin Bieber'

# %%
names.pop(14)
# Out:
# 'October 22, 2015'

# %%
names.pop(14)
# Out:
# '\n'

# %%
names.pop(14)
# Out:
# '14.'

# %%
names.pop(15)
# Out:
# 'Katy Perry'

# %%
names.pop(15)
# Out:
# '3.34'

# %%
names.pop(15)
# Out:
# 'September 5, 2013'

# %%
names.pop(15)
# Out:
# '\n'

# %%
names.pop(15)
# Out:
# '15.'

# %%
names.pop(16)
# Out:
# 'El Chombo'

# %%
names.pop(16)
# Out:
# '3.28'

# %%
names.pop(16)
# Out:
# 'April 5, 2018'

# %%
names.pop(16)
# Out:
# '\n'

# %%
names.pop(16)
# Out:
# '16.'

# %%
names.pop(17)
# Out:
# 'OneRepublic'

# %%
names.pop(17)
# Out:
# '3.27'

# %%
names.pop(17)
# Out:
# 'May 31, 2013'

# %%
names.pop(17)
# Out:
# '\n'

# %%
names.pop(17)
# Out:
# '17.'

# %%
names.pop(18)
# Out:
# 'Ed Sheeran'

# %%
names.pop(18)
# Out:
# '3.24'

# %%
names.pop(18)
# Out:
# 'October 7, 2014'

# %%
names.pop(18)
# Out:
# '\n'

# %%
names.pop(18)
# Out:
# '18.'

# %%
names.pop(19)
# Out:
# 'Katy Perry'

# %%
names.pop(19)
# Out:
# '3.05'

# %%
names.pop(19)
# Out:
# 'February 20, 2014'

# %%
names.pop(19)
# Out:
# '\n'

# %%
names.pop(19)
# Out:
# '19.'

# %%
names.pop(20)
# Out:
# 'Alan Walker'

# %%
names.pop(20)
# Out:
# '3.05'

# %%
names.pop(20)
# Out:
# 'December 3, 2015'

# %%
names.pop(20)
# Out:
# '\n'

# %%
names.pop(13)
# Out:
# '3.43'

# %%
names.pop(19)
# Out:
# '20.'

# %%
names.pop(20)
# Out:
# 'Taylor Swift'

# %%
names.pop(20)
# Out:
# '3.05'

# %%
names.pop(20)
# Out:
# 'August 18, 2014'

# %%
names.pop(20)
# Out:
# '\n'

# %%
names.pop(20)
# Out:
# '21.'

# %%
names[0:20]
# Out:
# ['"Baby Shark Dance"[22]',
#  '"Despacito"[24]',
#  '"Shape of You"[25]',
#  '"Johny Johny Yes Papa"[26]',
#  '"See You Again"[27]',
#  '"Masha and the Bear – Recipe for Disaster"[30]',
#  '"Uptown Funk"[31]',
#  '"Gangnam Style"[32]',
#  '"Learning Colors – Colorful Eggs on a Farm"[34]',
#  '"Bath Song"[35]',
#  '"Phonics Song with Two Words"[36]',
#  '"Sugar"[37]',
#  '"Sorry"[38]',
#  '"Roar"[39]',
#  '"Dame Tu Cosita"[40]',
#  '"Counting Stars"[41]',
#  '"Thinking Out Loud"[42]',
#  '"Dark Horse"[43]',
#  '"Faded"[44]',
#  '"Shake It Off"[45]']

# %%
video= soup.find_all('td')

# %%
videos=[]
for i in range(0,len(video)):
    videos.append(video[i].get_text())

# %%
videos.pop(0)
# Out:
# ''

# %%
videos.pop(1)
# Out:
# ''

# %%
videos.pop(2)
# Out:
# '1.'

# %%
videos.pop(0)
# Out:
# 'This article needs additional citations for verification. Please help improve this article by adding citations to reliable sources. Unsourced material may be challenged and removed.Find sources:\xa0"List of most-viewed YouTube videos"\xa0–\xa0news\xa0· newspapers\xa0· books\xa0· scholar\xa0· JSTOR (March 2021) (Learn how and when to remove this template message)'

# %%
videos.pop(0)
# Out:
# 'This section possibly contains original research. Please improve it by verifying the claims made and adding inline citations. Statements consisting only of original research should be removed. (March 2021) (Learn how and when to remove this template message)'

# %%
videos.pop(0)
# Out:
# '"Baby Shark Dance"[22]'

# %%
videos.pop(1)
# Out:
# '8.44'

# %%
videos.pop(1)
# Out:
# 'June 17, 2016'

# %%
videos.pop(1)
# Out:
# '[B]\n'

# %%
videos.pop(1)
# Out:
# '2.'

# %%
videos.pop(1)
# Out:
# '"Despacito"[24]'

# %%
videos.pop(2)
# Out:
# '7.32'

# %%
videos.pop(2)
# Out:
# 'January 12, 2017'

# %%
videos.pop(2)
# Out:
# '[C]\n'

# %%
videos.pop(2)
# Out:
# '3.'

# %%
videos.pop(2)
# Out:
# '"Shape of You"[25]'

# %%
videos.pop(3)
# Out:
# '5.29'

# %%
videos.pop(3)
# Out:
# 'January 30, 2017'

# %%
videos.pop(3)
# Out:
# '[D]\n'

# %%
videos.pop(3)
# Out:
# '4.'

# %%
videos.pop(3)
# Out:
# '"Johny Johny Yes Papa"[26]'

# %%
videos.pop(4)
# Out:
# '5.24'

# %%
videos.pop(4)
# Out:
# 'October 8, 2016'

# %%
videos.pop(4)
# Out:
# '[E]\n'

# %%
videos.pop(4)
# Out:
# '5.'

# %%
videos.pop(4)
# Out:
# '"See You Again"[27]'

# %%
videos.pop(5)
# Out:
# '5.08'

# %%
videos.pop(5)
# Out:
# 'April 6, 2015'

# %%
videos.pop(5)
# Out:
# '[F]\n'

# %%
videos.pop(5)
# Out:
# '6.'

# %%
videos.pop(5)
# Out:
# '"Masha and the Bear – Recipe for Disaster"[30]'

# %%
videos.pop(6)
# Out:
# '4.43'

# %%
videos.pop(6)
# Out:
# 'January 31, 2012'

# %%
videos.pop(6)
# Out:
# '[G]\n'

# %%
videos.pop(6)
# Out:
# '7.'

# %%
videos.pop(6)
# Out:
# '"Uptown Funk"[31]'

# %%
videos.pop(7)
# Out:
# '4.16'

# %%
videos.pop(7)
# Out:
# 'November 19, 2014'

# %%
videos.pop(7)
# Out:
# '[H]\n'

# %%
videos.pop(7)
# Out:
# '8.'

# %%
videos.pop(7)
# Out:
# '"Gangnam Style"[32]'

# %%
videos.pop(8)
# Out:
# '4.05'

# %%
videos.pop(8)
# Out:
# 'July 15, 2012'

# %%
videos.pop(8)
# Out:
# '[I]\n'

# %%
videos.pop(8)
# Out:
# '9.'

# %%
videos.pop(8)
# Out:
# '"Learning Colors – Colorful Eggs on a Farm"[34]'

# %%
videos.pop(9)
# Out:
# '3.97'

# %%
videos.pop(9)
# Out:
# 'February 27, 2018'

# %%
videos.pop(9)
# Out:
# '\n'

# %%
videos.pop(9)
# Out:
# '10.'

# %%
videos.pop(9)
# Out:
# '"Bath Song"[35]'

# %%
videos.pop(10)
# Out:
# '3.95'

# %%
videos.pop(10)
# Out:
# 'May 2, 2018'

# %%
videos.pop(10)
# Out:
# '\n'

# %%
videos.pop(10)
# Out:
# '11.'

# %%
videos.pop(10)
# Out:
# '"Phonics Song with Two Words"[36]'

# %%
videos.pop(11)
# Out:
# '3.78'

# %%
videos.pop(11)
# Out:
# 'March 6, 2014'

# %%
videos.pop(11)
# Out:
# '\n'

# %%
videos.pop(11)
# Out:
# '12.'

# %%
videos.pop(11)
# Out:
# '"Sugar"[37]'

# %%
videos.pop(12)
# Out:
# '3.45'

# %%
videos.pop(12)
# Out:
# 'January 14, 2015'

# %%
videos.pop(12)
# Out:
# '\n'

# %%
videos.pop(12)
# Out:
# '13.'

# %%
videos.pop(12)
# Out:
# '"Sorry"[38]'

# %%
videos.pop(13)
# Out:
# '3.43'

# %%
videos.pop(13)
# Out:
# 'October 22, 2015'

# %%
videos.pop(13)
# Out:
# '\n'

# %%
videos.pop(13)
# Out:
# '14.'

# %%
videos.pop(13)
# Out:
# '"Roar"[39]'

# %%
videos.pop(14)
# Out:
# '3.34'

# %%
videos.pop(14)
# Out:
# 'September 5, 2013'

# %%
videos.pop(14)
# Out:
# '\n'

# %%
videos.pop(14)
# Out:
# '15.'

# %%
videos.pop(14)
# Out:
# '"Dame Tu Cosita"[40]'

# %%
videos.pop(15)
# Out:
# '3.28'

# %%
videos.pop(15)
# Out:
# 'April 5, 2018'

# %%
videos.pop(15)
# Out:
# '\n'

# %%
videos.pop(15)
# Out:
# '16.'

# %%
videos.pop(15)
# Out:
# '"Counting Stars"[41]'

# %%
videos.pop(16)
# Out:
# '3.27'

# %%
videos.pop(16)
# Out:
# 'May 31, 2013'

# %%
videos.pop(16)
# Out:
# '\n'

# %%
videos.pop(16)
# Out:
# '17.'

# %%
videos.pop(16)
# Out:
# '"Thinking Out Loud"[42]'

# %%
videos.pop(17)
# Out:
# '3.24'

# %%
videos.pop(17)
# Out:
# 'October 7, 2014'

# %%
videos.pop(17)
# Out:
# '\n'

# %%
videos.pop(17)
# Out:
# '18.'

# %%
videos.pop(17)
# Out:
# '"Dark Horse"[43]'

# %%
videos.pop(18)
# Out:
# '3.05'

# %%
videos.pop(18)
# Out:
# 'February 20, 2014'

# %%
videos.pop(18)
# Out:
# '\n'

# %%
videos.pop(18)
# Out:
# '19.'

# %%
videos.pop(18)
# Out:
# '"Faded"[44]'

# %%
videos.pop(19)
# Out:
# '3.05'

# %%
videos.pop(19)
# Out:
# 'December 3, 2015'

# %%
videos.pop(19)
# Out:
# '\n'

# %%
videos.pop(19)
# Out:
# '20.'

# %%
videos.pop(19)
# Out:
# '"Shake It Off"[45]'

# %%
videos.pop(20)
# Out:
# '3.05'

# %%
videos.pop(20)
# Out:
# 'August 18, 2014'

# %%
videos.pop(20)
# Out:
# '\n'

# %%
videos.pop(20)
# Out:
# '21.'

# %%
videos.pop(20)
# Out:
# '"Lean On"[46]'

# %%
videos[0:20]
# Out:
# ["Pinkfong Kids' Songs & Stories",
#  'Luis Fonsi',
#  'Ed Sheeran',
#  'LooLoo Kids',
#  'Wiz Khalifa',
#  'Get Movies',
#  'Mark Ronson',
#  'Psy',
#  'Miroshka TV',
#  'Cocomelon – Nursery Rhymes',
#  'ChuChu TV',
#  'Maroon 5',
#  'Justin Bieber',
#  'Katy Perry',
#  'El Chombo',
#  'OneRepublic',
#  'Ed Sheeran',
#  'Katy Perry',
#  'Alan Walker',
#  'Taylor Swift']

# %%
views=soup.find_all('td')

# %%
view=[]
for i in range(0,len(views)):
    view.append(views[i].get_text())

# %%
view.pop(0)
# Out:
# ''

# %%
view.pop(1)
# Out:
# ''

# %%
view.pop(0)
# Out:
# 'This article needs additional citations for verification. Please help improve this article by adding citations to reliable sources. Unsourced material may be challenged and removed.Find sources:\xa0"List of most-viewed YouTube videos"\xa0–\xa0news\xa0· newspapers\xa0· books\xa0· scholar\xa0· JSTOR (March 2021) (Learn how and when to remove this template message)'

# %%
view.pop(0)
# Out:
# 'This section possibly contains original research. Please improve it by verifying the claims made and adding inline citations. Statements consisting only of original research should be removed. (March 2021) (Learn how and when to remove this template message)'

# %%
view.pop(0)
# Out:
# '1.'

# %%
view.pop(0)
# Out:
# '"Baby Shark Dance"[22]'

# %%
view.pop(0)
# Out:
# "Pinkfong Kids' Songs & Stories"

# %%
view.pop(1)
# Out:
# 'June 17, 2016'

# %%
view.pop(1)
# Out:
# '[B]\n'

# %%
view.pop(1)
# Out:
# '2.'

# %%
view.pop(1)
# Out:
# '"Despacito"[24]'

# %%
view.pop(1)
# Out:
# 'Luis Fonsi'

# %%
view.pop(2)
# Out:
# 'January 12, 2017'

# %%
view.pop(2)
# Out:
# '[C]\n'

# %%
view.pop(2)
# Out:
# '3.'

# %%
view.pop(2)
# Out:
# '"Shape of You"[25]'

# %%
view.pop(2)
# Out:
# 'Ed Sheeran'

# %%
view.pop(3)
# Out:
# 'January 30, 2017'

# %%
view.pop(4)
# Out:
# '4.'

# %%
view.pop(4)
# Out:
# '"Johny Johny Yes Papa"[26]'

# %%
view.pop(4)
# Out:
# 'LooLoo Kids'

# %%
view.pop(5)
# Out:
# 'October 8, 2016'

# %%
view.pop(5)
# Out:
# '[E]\n'

# %%
view.pop(6)
# Out:
# '"See You Again"[27]'

# %%
view.pop(6)
# Out:
# 'Wiz Khalifa'

# %%
view.pop(7)
# Out:
# 'April 6, 2015'

# %%
view.pop(7)
# Out:
# '[F]\n'

# %%
view.pop(7)
# Out:
# '6.'

# %%
view.pop(7)
# Out:
# '"Masha and the Bear – Recipe for Disaster"[30]'

# %%
view.pop(7)
# Out:
# 'Get Movies'

# %%
view.pop(8)
# Out:
# 'January 31, 2012'

# %%
view.pop(8)
# Out:
# '[G]\n'

# %%
view.pop(8)
# Out:
# '7.'

# %%
view.pop(8)
# Out:
# '"Uptown Funk"[31]'

# %%
view.pop(8)
# Out:
# 'Mark Ronson'

# %%
view.pop(9)
# Out:
# 'November 19, 2014'

# %%
view.pop(9)
# Out:
# '[H]\n'

# %%
view.pop(9)
# Out:
# '8.'

# %%
view.pop(9)
# Out:
# '"Gangnam Style"[32]'

# %%
view.pop(9)
# Out:
# 'Psy'

# %%
view.pop(10)
# Out:
# 'July 15, 2012'

# %%
view.pop(10)
# Out:
# '[I]\n'

# %%
view.pop(10)
# Out:
# '9.'

# %%
view.pop(10)
# Out:
# '"Learning Colors – Colorful Eggs on a Farm"[34]'

# %%
view.pop(10)
# Out:
# 'Miroshka TV'

# %%
view.pop(11)
# Out:
# 'February 27, 2018'

# %%
view.pop(11)
# Out:
# '\n'

# %%
view.pop(11)
# Out:
# '10.'

# %%
view.pop(11)
# Out:
# '"Bath Song"[35]'

# %%
view.pop(11)
# Out:
# 'Cocomelon – Nursery Rhymes'

# %%
view.pop(12)
# Out:
# 'May 2, 2018'

# %%
view.pop(12)
# Out:
# '\n'

# %%
view.pop(12)
# Out:
# '11.'

# %%
view.pop(12)
# Out:
# '"Phonics Song with Two Words"[36]'

# %%
view.pop(12)
# Out:
# 'ChuChu TV'

# %%
view.pop(13)
# Out:
# 'March 6, 2014'

# %%
view.pop(13)
# Out:
# '\n'

# %%
view.pop(13)
# Out:
# '12.'

# %%
view.pop(13)
# Out:
# '"Sugar"[37]'

# %%
view.pop(13)
# Out:
# 'Maroon 5'

# %%
view.pop(14)
# Out:
# 'January 14, 2015'

# %%
view.pop(14)
# Out:
# '\n'

# %%
view.pop(14)
# Out:
# '13.'

# %%
view.pop(14)
# Out:
# '"Sorry"[38]'

# %%
view.pop(14)
# Out:
# 'Justin Bieber'

# %%
view.pop(15)
# Out:
# 'October 22, 2015'

# %%
view.pop(15)
# Out:
# '\n'

# %%
view.pop(15)
# Out:
# '14.'

# %%
view.pop(15)
# Out:
# '"Roar"[39]'

# %%
view.pop(15)
# Out:
# 'Katy Perry'

# %%
view.pop(16)
# Out:
# 'September 5, 2013'

# %%
view.pop(16)
# Out:
# '\n'

# %%
view.pop(16)
# Out:
# '15.'

# %%
view.pop(16)
# Out:
# '"Dame Tu Cosita"[40]'

# %%
view.pop(16)
# Out:
# 'El Chombo'

# %%
view.pop(17)
# Out:
# 'April 5, 2018'

# %%
view.pop(17)
# Out:
# '\n'

# %%
view.pop(17)
# Out:
# '16.'

# %%
view.pop(17)
# Out:
# '"Counting Stars"[41]'

# %%
view.pop(17)
# Out:
# 'OneRepublic'

# %%
view.pop(18)
# Out:
# 'May 31, 2013'

# %%
view.pop(18)
# Out:
# '\n'

# %%
view.pop(18)
# Out:
# '17.'

# %%
view.pop(18)
# Out:
# '"Thinking Out Loud"[42]'

# %%
view.pop(18)
# Out:
# 'Ed Sheeran'

# %%
view.pop(19)
# Out:
# 'October 7, 2014'

# %%
view.pop(19)
# Out:
# '\n'

# %%
view.pop(19)
# Out:
# '18.'

# %%
view.pop(19)
# Out:
# '"Dark Horse"[43]'

# %%
view.pop(19)
# Out:
# 'Katy Perry'

# %%
view.pop(20)
# Out:
# 'February 20, 2014'

# %%
view.pop(20)
# Out:
# '\n'

# %%
view.pop(20)
# Out:
# '19.'

# %%
view.pop(20)
# Out:
# '"Faded"[44]'

# %%
view.pop(20)
# Out:
# 'Alan Walker'

# %%
view.pop(3)
# Out:
# '[D]\n'

# %%
view.pop(4)
# Out:
# '5.'

# %%
view.pop(19)
# Out:
# 'December 3, 2015'

# %%
view.pop(19)
# Out:
# '\n'

# %%
view.pop(19)
# Out:
# '20.'

# %%
view.pop(19)
# Out:
# '"Shake It Off"[45]'

# %%
view.pop(19)
# Out:
# 'Taylor Swift'

# %%
view[0:20]
# Out:
# ['8.44',
#  '7.32',
#  '5.29',
#  '5.24',
#  '5.08',
#  '4.43',
#  '4.16',
#  '4.05',
#  '3.97',
#  '3.95',
#  '3.78',
#  '3.45',
#  '3.43',
#  '3.34',
#  '3.28',
#  '3.27',
#  '3.24',
#  '3.05',
#  '3.05',
#  '3.05']

# %%
dated=soup.find_all('td')

# %%
date=[]
for i in range(0,len(dated)):
    date.append(dated[i].get_text())

# %%
date.pop(0)
# Out:
# ''

# %%
date.pop(0)
# Out:
# 'This article needs additional citations for verification. Please help improve this article by adding citations to reliable sources. Unsourced material may be challenged and removed.Find sources:\xa0"List of most-viewed YouTube videos"\xa0–\xa0news\xa0· newspapers\xa0· books\xa0· scholar\xa0· JSTOR (March 2021) (Learn how and when to remove this template message)'

# %%
date.pop(0)
# Out:
# ''

# %%
date.pop(0)
# Out:
# 'This section possibly contains original research. Please improve it by verifying the claims made and adding inline citations. Statements consisting only of original research should be removed. (March 2021) (Learn how and when to remove this template message)'

# %%
date.pop(0)
# Out:
# '1.'

# %%
date.pop(0)
# Out:
# '"Baby Shark Dance"[22]'

# %%
date.pop(0)
# Out:
# "Pinkfong Kids' Songs & Stories"

# %%
date.pop(0)
# Out:
# '8.44'

# %%
date.pop(1)
# Out:
# '[B]\n'

# %%
date.pop(1)
# Out:
# '2.'

# %%
date.pop(1)
# Out:
# '"Despacito"[24]'

# %%
date.pop(1)
# Out:
# 'Luis Fonsi'

# %%
date.pop(1)
# Out:
# '7.32'

# %%
date.pop(2)
# Out:
# '[C]\n'

# %%
date.pop(2)
# Out:
# '3.'

# %%
date.pop(2)
# Out:
# '"Shape of You"[25]'

# %%
date.pop(2)
# Out:
# 'Ed Sheeran'

# %%
date.pop(2)
# Out:
# '5.29'

# %%
date.pop(3)
# Out:
# '[D]\n'

# %%
date.pop(3)
# Out:
# '4.'

# %%
date.pop(4)
# Out:
# 'LooLoo Kids'

# %%
date.pop(4)
# Out:
# '5.24'

# %%
date.pop(5)
# Out:
# '[E]\n'

# %%
date.pop(5)
# Out:
# '5.'

# %%
date.pop(5)
# Out:
# '"See You Again"[27]'

# %%
date.pop(5)
# Out:
# 'Wiz Khalifa'

# %%
date.pop(5)
# Out:
# '5.08'

# %%
date.pop(6)
# Out:
# '[F]\n'

# %%
date.pop(6)
# Out:
# '6.'

# %%
date.pop(6)
# Out:
# '"Masha and the Bear – Recipe for Disaster"[30]'

# %%
date.pop(6)
# Out:
# 'Get Movies'

# %%
date.pop(6)
# Out:
# '4.43'

# %%
date.pop(7)
# Out:
# '[G]\n'

# %%
date.pop(7)
# Out:
# '7.'

# %%
date.pop(7)
# Out:
# '"Uptown Funk"[31]'

# %%
date.pop(7)
# Out:
# 'Mark Ronson'

# %%
date.pop(7)
# Out:
# '4.16'

# %%
date.pop(8)
# Out:
# '[H]\n'

# %%
date.pop(8)
# Out:
# '8.'

# %%
date.pop(9)
# Out:
# 'Psy'

# %%
date.pop(9)
# Out:
# '4.05'

# %%
date.pop(10)
# Out:
# '[I]\n'

# %%
date.pop(10)
# Out:
# '9.'

# %%
date.pop(10)
# Out:
# '"Learning Colors – Colorful Eggs on a Farm"[34]'

# %%
date.pop(10)
# Out:
# 'Miroshka TV'

# %%
date.pop(10)
# Out:
# '3.97'

# %%
date.pop(11)
# Out:
# '\n'

# %%
date.pop(11)
# Out:
# '10.'

# %%
date.pop(11)
# Out:
# '"Bath Song"[35]'

# %%
date.pop(11)
# Out:
# 'Cocomelon – Nursery Rhymes'

# %%
date.pop(11)
# Out:
# '3.95'

# %%
date.pop(12)
# Out:
# '\n'

# %%
date.pop(12)
# Out:
# '11.'

# %%
date.pop(12)
# Out:
# '"Phonics Song with Two Words"[36]'

# %%
date.pop(12)
# Out:
# 'ChuChu TV'

# %%
date.pop(12)
# Out:
# '3.78'

# %%
date.pop(13)
# Out:
# '\n'

# %%
date.pop(13)
# Out:
# '12.'

# %%
date.pop(13)
# Out:
# '"Sugar"[37]'

# %%
date.pop(13)
# Out:
# 'Maroon 5'

# %%
date.pop(13)
# Out:
# '3.45'

# %%
date.pop(14)
# Out:
# '\n'

# %%
date.pop(14)
# Out:
# '13.'

# %%
date.pop(14)
# Out:
# '"Sorry"[38]'

# %%
date.pop(14)
# Out:
# 'Justin Bieber'

# %%
date.pop(14)
# Out:
# '3.43'

# %%
date.pop(3)
# Out:
# '"Johny Johny Yes Papa"[26]'

# %%
date.pop(7)
# Out:
# '"Gangnam Style"[32]'

# %%
date.pop(13)
# Out:
# '\n'

# %%
date.pop(13)
# Out:
# '14.'

# %%
date.pop(14)
# Out:
# 'Katy Perry'

# %%
date.pop(14)
# Out:
# '3.34'

# %%
date.pop(15)
# Out:
# '\n'

# %%
date.pop(15)
# Out:
# '15.'

# %%
date.pop(16)
# Out:
# 'El Chombo'

# %%
date.pop(16)
# Out:
# '3.28'

# %%
date.pop(13)
# Out:
# '"Roar"[39]'

# %%
date.pop(14)
# Out:
# '"Dame Tu Cosita"[40]'

# %%
date.pop(16)
# Out:
# '16.'

# %%
date.pop(16)
# Out:
# '"Counting Stars"[41]'

# %%
date.pop(16)
# Out:
# 'OneRepublic'

# %%
date.pop(16)
# Out:
# '3.27'

# %%
date.pop(17)
# Out:
# '\n'

# %%
date.pop(17)
# Out:
# '17.'

# %%
date.pop(17)
# Out:
# '"Thinking Out Loud"[42]'

# %%
date.pop(17)
# Out:
# 'Ed Sheeran'

# %%
date.pop(17)
# Out:
# '3.24'

# %%
date.pop(18)
# Out:
# '\n'

# %%
date.pop(18)
# Out:
# '18.'

# %%
date.pop(19)
# Out:
# 'Katy Perry'

# %%
date.pop(19)
# Out:
# '3.05'

# %%
date.pop(20)
# Out:
# '\n'

# %%
date.pop(20)
# Out:
# '19.'

# %%
date.pop(20)
# Out:
# '"Faded"[44]'

# %%
date.pop(20)
# Out:
# 'Alan Walker'

# %%
date.pop(20)
# Out:
# '3.05'

# %%
date.pop(18)
# Out:
# '"Dark Horse"[43]'

# %%
date.pop(15)
# Out:
# '\n'

# %%
date.pop(20)
# Out:
# '20.'

# %%
date.pop(20)
# Out:
# '"Shake It Off"[45]'

# %%
date.pop(20)
# Out:
# 'Taylor Swift'

# %%
date.pop(20)
# Out:
# '3.05'

# %%
date.pop(19)
# Out:
# '\n'

# %%
date[0:20]
# Out:
# ['June 17, 2016',
#  'January 12, 2017',
#  'January 30, 2017',
#  'October 8, 2016',
#  'April 6, 2015',
#  'January 31, 2012',
#  'November 19, 2014',
#  'July 15, 2012',
#  'February 27, 2018',
#  'May 2, 2018',
#  'March 6, 2014',
#  'January 14, 2015',
#  'October 22, 2015',
#  'September 5, 2013',
#  'April 5, 2018',
#  'May 31, 2013',
#  'October 7, 2014',
#  'February 20, 2014',
#  'December 3, 2015',
#  'August 18, 2014']

# %%
import pandas as pd
most_viewed=pd.DataFrame({})
most_viewed['Video Names']=names[0:20]
most_viewed['Uploader']=videos[0:20]
most_viewed['Views']=view[0:20]
most_viewed['Date']=date[0:20]

# %%
most_viewed
# Out:
#                                         Video Names  \
# 0                            "Baby Shark Dance"[22]
# 1                                   "Despacito"[24]
# 2                                "Shape of You"[25]
# 3                        "Johny Johny Yes Papa"[26]
# 4                               "See You Again"[27]
# 5    "Masha and the Bear – Recipe for Disaster"[30]
# 6                                 "Uptown Funk"[31]
# 7                               "Gangnam Style"[32]
# 8   "Learning Colors – Colorful Eggs on a Farm"[34]
# 9                                   "Bath Song"[35]
# 10                "Phonics Song with Two Words"[36]
# 11                                      "Sugar"[37]
# 12                                      "Sorry"[38]
# 13                                       "Roar"[39]
# 14                             "Dame Tu Cosita"[40]
# 15                             "Counting Stars"[41]
# 16                          "Thinking Out Loud"[42]
# ...
