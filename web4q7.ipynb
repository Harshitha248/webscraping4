# %% [raw]
# Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code

# %%
import pandas as pd
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
import requests
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://www.naukri.com/")
from bs4 import BeautifulSoup

# %%
search_field_designation=browser.find_element_by_id("qsb-keyword-sugg")
search_field_location=browser.find_element_by_id('qsb-location-sugg')
search_field_designation.send_keys("Data Analyst")
search_field_location.send_keys("Bangalore")

# %%
# clicking the search button
search_button=browser.find_element_by_xpath("//div[@class='search-btn']/button")
search_button.click()

# %%
titles=[]

# %%
title_tags=browser.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for i in name_tags:
    if i.text is None :
        titles.append("no rating") 
    else:
        titles.append(i.text)

# %%
titles
# Out:
# ['Data Analyst',
#  'Hiring Data Analysts For E commerce Platform || WFH',
#  'Assistant Manager II - Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'DA - Urgent Opening For Data Analyst BFSI Domain - Pan India',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst - Work from Home',
#  'Data Analyst Scada Systems & Database Management',
#  'Sybase SQL with Post trade/ settlement Data Analyst',
#  'Senior/Regular Business Analyst / Data Analyst',
#  'Data Analyst',
#  'Hiring For Data Analyst',
#  'Business Data Analyst - MIS & Reporting',
#  'Data Analyst / Business Analyst -']

# %%
company=[]

# %%
company_tags=browser.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
for i in designation_tags:
    if i.text is None :
        company.append("no rating") 
    else:
        company.append(i.text)

# %%
company
# Out:
# ['GlaxoSmithKline Pharmaceuticals Limited',
#  'Allegis Services India Pvt. Ltd.',
#  'Flipkart Internet Private Limited',
#  'Shell India Markets Private Limited',
#  'Applied Materials',
#  'Tata Consultancy Services Ltd.',
#  'Shell India Markets Private Limited',
#  'Myntra Designs Pvt. Ltd.',
#  'Myntra Designs Pvt. Ltd.',
#  'Myntra Designs Pvt. Ltd.',
#  'Myntra Designs Pvt. Ltd.',
#  'Myntra Designs Pvt. Ltd.',
#  'POWER STORES E COMMERCE PRIVATE LIMITED',
#  'SmartHelio Sarl',
#  'Larsen & Toubro Infotech Limited',
#  'Luxoft',
#  'IBM India Pvt. Limited',
#  'Flipkart Internet Private Limited',
#  'INTERTRUST GROUP',
#  'LatentView Analytics Private Limited']

# %%
company=[]

# %%
<a href="https://www.naukri.com/glaxosmithkline-pharmaceuticals-jobs-careers-16369" class="subTitle ellipsis fleft" target="_blank" title="GlaxoSmithKline Pharmaceuticals Limited">GlaxoSmithKline Pharmaceuticals Limited</a>

# %%
company_tags=browser.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
for i in company_tags:
    if i.text is None :
        company.append("no rating") 
    else:
        company.append(i.text)

# %%
company
# Out:
# ['GlaxoSmithKline Pharmaceuticals Limited',
#  'Allegis Services India Pvt. Ltd.',
#  'Flipkart Internet Private Limited',
#  'Shell India Markets Private Limited',
#  'Applied Materials',
#  'Tata Consultancy Services Ltd.',
#  'Shell India Markets Private Limited',
#  'Myntra Designs Pvt. Ltd.',
#  'Myntra Designs Pvt. Ltd.',
#  'Myntra Designs Pvt. Ltd.',
#  'Myntra Designs Pvt. Ltd.',
#  'Myntra Designs Pvt. Ltd.',
#  'POWER STORES E COMMERCE PRIVATE LIMITED',
#  'SmartHelio Sarl',
#  'Larsen & Toubro Infotech Limited',
#  'Luxoft',
#  'IBM India Pvt. Limited',
#  'Flipkart Internet Private Limited',
#  'INTERTRUST GROUP',
#  'LatentView Analytics Private Limited']

# %%
skill=[]

# %%
skill_tags=browser.find_elements_by_xpath("//ul[@class='fleft fs12 grey-text lh16 dot']/li[0]")
for i in skill_tags:
    if i.text is None :
        skill.append("no rating") 
    else:
        skill.append(i.text)

# %%
skill
# Out:
# ['Condition\nProduct Development\nR\nData Quality\nAzure\nData Analysis\nData Modeling\nData Analytics',
#  'Hive\nExcel\nData Analysis\nData Modeling\nData Warehousing\nReporting Tools\nAnalytics\nSQL',
#  'R\nPower BI\nAccounting\nArtificial Intelligence\nAlteryx\nData Analysis\nData Extraction\nData Cleansing',
#  'Data Validation\nAzure Data Lake Store\nAzure Data Factory\nData Management\nConditional Formatting\nMacros\nSQL programming\nExcel',
#  'Real Time Analysis\nData Management\nData Analysis\nData Mining\nData Collection\nTableau\nData Analytics',
#  'Banking\nData Collection\nData Quality\nLoan Origination\nSegmentation\nRisk Assessment\nBusiness Analysis\nSQL',
#  'Data Validation\nExcel\nData Management\nConditional Formatting\nFormulas\nCharts\nAzure Data Lake\nPivot',
#  'R\nExcel\nData Analysis\nTableau\nData Analytics\nSQL\nPython',
#  'R\nExcel\nData Analysis\nBusiness Insights\nTableau\nData Analytics\nConsumer Insights\nMarket Research',
#  'Excel\nData Engineering\nData Analysis\nBusiness Insights\nData Analyst\nData Analytics\nStatistics\nConsumer Insights',
#  'R\nExcel\nData Analysis\nBusiness Insights\nTableau\nData Analytics\nConsumer Insights\nMarket Research',
#  'R\nExcel\nData visualization\nData Analysis\nBusiness Insights\nTableau\nData Analytics\nSQL',
#  'Data Analysis\nCollection Management\nExcel\nProcess Improvement\nData Collection\nTableau\nData Warehousing\nData Analytics',
#  'Database\nMPLS\nSCADA\nIT Skills\nMachine Learning\nArtificial Intelligence\nCloud\nPower Plant',
#  'Unix\nSybase SQL\nCapital markets\nJava\nIT Skills\nTechnical Analysis\nData Analysis\nsettelement',
#  'analytics\nAgile Methodology\nRetail\nData validation\nDiagnostics\nBusiness Analyst\nBusiness analysis\nData Analyst',
#  'Business Intelligence\nData Reconciliation\nScrum Master\nSCALA\nAgile\nSQL Queries\nData Cleansing\nSpark',
#  'Pivot Table\nSUMIF\nR\nVBA\nVLOOKUP\nTableau\nHLOOKUP\nSQL',
#  'Power Bi\nSQL Server\nTableau\nSpotfire\nMS Visio\nSSRS\nAlteryx\nData Transformation Services',
#  'Predictive Modeling\nData analyst\nBusiness Analytics\nPower Bi\nStatistical Programming\nText Mining\nTableau\nMachine Learning',
#  'Condition\nProduct Development\nR\nData Quality\nAzure\nData Analysis\nData Modeling\nData Analytics',
#  'Hive\nExcel\nData Analysis\nData Modeling\nData Warehousing\nReporting Tools\nAnalytics\nSQL',
#  'R\nPower BI\nAccounting\nArtificial Intelligence\nAlteryx\nData Analysis\nData Extraction\nData Cleansing',
#  'Data Validation\nAzure Data Lake Store\nAzure Data Factory\nData Management\nConditional Formatting\nMacros\nSQL programming\nExcel',
#  'Real Time Analysis\nData Management\nData Analysis\nData Mining\nData Collection\nTableau\nData Analytics',
#  'Banking\nData Collection\nData Quality\nLoan Origination\nSegmentation\nRisk Assessment\nBusiness Analysis\nSQL',
#  'Data Validation\nExcel\nData Management\nConditional Formatting\nFormulas\nCharts\nAzure Data Lake\nPivot',
#  'R\nExcel\nData Analysis\nTableau\nData Analytics\nSQL\nPython',
#  'R\nExcel\nData Analysis\nBusiness Insights\nTableau\nData Analytics\nConsumer Insights\nMarket Research',
#  'Excel\nData Engineering\nData Analysis\nBusiness Insights\nData Analyst\nData Analytics\nStatistics\nConsumer Insights',
#  'R\nExcel\nData Analysis\nBusiness Insights\nTableau\nData Analytics\nConsumer Insights\nMarket Research',
#  'R\nExcel\nData visualization\nData Analysis\nBusiness Insights\nTableau\nData Analytics\nSQL',
#  'Data Analysis\nCollection Management\nExcel\nProcess Improvement\nData Collection\nTableau\nData Warehousing\nData Analytics',
#  'Database\nMPLS\nSCADA\nIT Skills\nMachine Learning\nArtificial Intelligence\nCloud\nPower Plant',
#  'Unix\nSybase SQL\nCapital markets\nJava\nIT Skills\nTechnical Analysis\nData Analysis\nsettelement',
#  'analytics\nAgile Methodology\nRetail\nData validation\nDiagnostics\nBusiness Analyst\nBusiness analysis\nData Analyst',
#  'Business Intelligence\nData Reconciliation\nScrum Master\nSCALA\nAgile\nSQL Queries\nData Cleansing\nSpark',
#  'Pivot Table\nSUMIF\nR\nVBA\nVLOOKUP\nTableau\nHLOOKUP\nSQL',
#  'Power Bi\nSQL Server\nTableau\nSpotfire\nMS Visio\nSSRS\nAlteryx\nData Transformation Services',
#  'Predictive Modeling\nData analyst\nBusiness Analytics\nPower Bi\nStatistical Programming\nText Mining\nTableau\nMachine Learning',
#  'ConditionProduct DevelopmentRData QualityAzureData AnalysisData ModelingData Analytics',
#  'HiveExcelData AnalysisData ModelingData WarehousingReporting ToolsAnalyticsSQL',
#  'RPower BIAccountingArtificial IntelligenceAlteryxData AnalysisData ExtractionData Cleansing',
#  'Data ValidationAzure Data Lake StoreAzure Data FactoryData ManagementConditional FormattingMacrosSQL programmingExcel',
#  'Real Time AnalysisData ManagementData AnalysisData MiningData CollectionTableauData Analytics',
#  'BankingData CollectionData QualityLoan OriginationSegmentationRisk AssessmentBusiness AnalysisSQL',
#  'Data ValidationExcelData ManagementConditional FormattingFormulasChartsAzure Data LakePivot',
#  'RExcelData AnalysisTableauData AnalyticsSQLPython',
#  'RExcelData AnalysisBusiness InsightsTableauData AnalyticsConsumer InsightsMarket Research',
#  'ExcelData EngineeringData AnalysisBusiness InsightsData AnalystData AnalyticsStatisticsConsumer Insights',
#  'RExcelData AnalysisBusiness InsightsTableauData AnalyticsConsumer InsightsMarket Research',
#  'RExcelData visualizationData AnalysisBusiness InsightsTableauData AnalyticsSQL',
#  'Data AnalysisCollection ManagementExcelProcess ImprovementData CollectionTableauData WarehousingData Analytics',
#  'DatabaseMPLSSCADAIT SkillsMachine LearningArtificial IntelligenceCloudPower Plant',
#  'UnixSybase SQLCapital marketsJavaIT SkillsTechnical AnalysisData Analysissettelement',
#  'analyticsAgile MethodologyRetailData validationDiagnosticsBusiness AnalystBusiness analysisData Analyst',
#  'Business IntelligenceData ReconciliationScrum MasterSCALAAgileSQL QueriesData CleansingSpark',
#  'Pivot TableSUMIFRVBAVLOOKUPTableauHLOOKUPSQL',
#  'Power BiSQL ServerTableauSpotfireMS VisioSSRSAlteryxData Transformation Services',
#  'Predictive ModelingData analystBusiness AnalyticsPower BiStatistical ProgrammingText MiningTableauMachine Learning',
#  'Condition\nProduct Development\nR\nData Quality\nAzure\nData Analysis\nData Modeling\nData Analytics',
#  'Hive\nExcel\nData Analysis\nData Modeling\nData Warehousing\nReporting Tools\nAnalytics\nSQL',
#  'R\nPower BI\nAccounting\nArtificial Intelligence\nAlteryx\nData Analysis\nData Extraction\nData Cleansing',
#  'Data Validation\nAzure Data Lake Store\nAzure Data Factory\nData Management\nConditional Formatting\nMacros\nSQL programming\nExcel',
#  'Real Time Analysis\nData Management\nData Analysis\nData Mining\nData Collection\nTableau\nData Analytics',
#  'Banking\nData Collection\nData Quality\nLoan Origination\nSegmentation\nRisk Assessment\nBusiness Analysis\nSQL',
#  'Data Validation\nExcel\nData Management\nConditional Formatting\nFormulas\nCharts\nAzure Data Lake\nPivot',
#  'R\nExcel\nData Analysis\nTableau\nData Analytics\nSQL\nPython',
#  'R\nExcel\nData Analysis\nBusiness Insights\nTableau\nData Analytics\nConsumer Insights\nMarket Research',
#  'Excel\nData Engineering\nData Analysis\nBusiness Insights\nData Analyst\nData Analytics\nStatistics\nConsumer Insights',
#  'R\nExcel\nData Analysis\nBusiness Insights\nTableau\nData Analytics\nConsumer Insights\nMarket Research',
#  'R\nExcel\nData visualization\nData Analysis\nBusiness Insights\nTableau\nData Analytics\nSQL',
#  'Data Analysis\nCollection Management\nExcel\nProcess Improvement\nData Collection\nTableau\nData Warehousing\nData Analytics',
#  'Database\nMPLS\nSCADA\nIT Skills\nMachine Learning\nArtificial Intelligence\nCloud\nPower Plant',
#  'Unix\nSybase SQL\nCapital markets\nJava\nIT Skills\nTechnical Analysis\nData Analysis\nsettelement',
#  'analytics\nAgile Methodology\nRetail\nData validation\nDiagnostics\nBusiness Analyst\nBusiness analysis\nData Analyst',
#  'Business Intelligence\nData Reconciliation\nScrum Master\nSCALA\nAgile\nSQL Queries\nData Cleansing\nSpark',
#  'Pivot Table\nSUMIF\nR\nVBA\nVLOOKUP\nTableau\nHLOOKUP\nSQL',
#  'Power Bi\nSQL Server\nTableau\nSpotfire\nMS Visio\nSSRS\nAlteryx\nData Transformation Services',
#  'Predictive Modeling\nData analyst\nBusiness Analytics\nPower Bi\nStatistical Programming\nText Mining\nTableau\nMachine Learning',
#  'Condition',
#  'Product Development',
#  'R',
#  'Data Quality',
#  'Azure',
#  'Data Analysis',
#  'Data Modeling',
#  'Data Analytics',
#  'Hive',
#  'Excel',
#  'Data Analysis',
#  'Data Modeling',
#  'Data Warehousing',
#  'Reporting Tools',
#  'Analytics',
#  'SQL',
#  'R',
#  'Power BI',
#  'Accounting',
#  'Artificial Intelligence',
#  'Alteryx',
#  'Data Analysis',
#  'Data Extraction',
#  'Data Cleansing',
#  'Data Validation',
#  'Azure Data Lake Store',
#  'Azure Data Factory',
#  'Data Management',
#  'Conditional Formatting',
#  'Macros',
#  'SQL programming',
#  'Excel',
#  'Real Time Analysis',
#  'Data Management',
#  'Data Analysis',
#  'Data Mining',
#  'Data Collection',
#  'Tableau',
#  'Data Analytics',
#  'Banking',
#  'Data Collection',
#  'Data Quality',
#  'Loan Origination',
#  'Segmentation',
#  'Risk Assessment',
#  'Business Analysis',
#  'SQL',
#  'Data Validation',
#  'Excel',
#  'Data Management',
#  'Conditional Formatting',
#  'Formulas',
#  'Charts',
#  'Azure Data Lake',
#  'Pivot',
#  'R',
#  'Excel',
#  'Data Analysis',
#  'Tableau',
#  'Data Analytics',
#  'SQL',
#  'Python',
#  'R',
#  'Excel',
#  'Data Analysis',
#  'Business Insights',
#  'Tableau',
#  'Data Analytics',
#  'Consumer Insights',
#  'Market Research',
#  'Excel',
#  'Data Engineering',
#  'Data Analysis',
#  'Business Insights',
#  'Data Analyst',
#  'Data Analytics',
#  'Statistics',
#  'Consumer Insights',
#  'R',
#  'Excel',
#  'Data Analysis',
#  'Business Insights',
#  'Tableau',
#  'Data Analytics',
#  'Consumer Insights',
#  'Market Research',
#  'R',
#  'Excel',
#  'Data visualization',
#  'Data Analysis',
#  'Business Insights',
#  'Tableau',
#  'Data Analytics',
#  'SQL',
#  'Data Analysis',
#  'Collection Management',
#  'Excel',
#  'Process Improvement',
#  'Data Collection',
#  'Tableau',
#  'Data Warehousing',
#  'Data Analytics',
#  'Database',
#  'MPLS',
#  'SCADA',
#  'IT Skills',
#  'Machine Learning',
#  'Artificial Intelligence',
#  'Cloud',
#  'Power Plant',
#  'Unix',
#  'Sybase SQL',
#  'Capital markets',
#  'Java',
#  'IT Skills',
#  'Technical Analysis',
#  'Data Analysis',
#  'settelement',
#  'analytics',
#  'Agile Methodology',
#  'Retail',
#  'Data validation',
#  'Diagnostics',
#  'Business Analyst',
#  'Business analysis',
#  'Data Analyst',
#  'Business Intelligence',
#  'Data Reconciliation',
#  'Scrum Master',
#  'SCALA',
#  'Agile',
#  'SQL Queries',
#  'Data Cleansing',
#  'Spark',
#  'Pivot Table',
#  'SUMIF',
#  'R',
#  'VBA',
#  'VLOOKUP',
#  'Tableau',
#  'HLOOKUP',
#  'SQL',
#  'Power Bi',
#  'SQL Server',
#  'Tableau',
#  'Spotfire',
#  'MS Visio',
#  'SSRS',
#  'Alteryx',
#  'Data Transformation Services',
#  'Predictive Modeling',
#  'Data analyst',
#  'Business Analytics',
#  'Power Bi',
#  'Statistical Programming',
#  'Text Mining',
#  'Tableau',
#  'Machine Learning']

# %%
job_location=[]

# %%
#scraping the job-location
locations=browser.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span[1]")
for i in locations:
    if i.text is None :
        job_location.append("--") 
    else:
        job_location.append(i.text)
job_location
# Out:
# ['Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Kolkata, Hyderabad/Secunderabad, Pune, Ahmedabad, Chennai, Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Pune, Bangalore/Bengaluru, Mumbai (All Areas)',
#  'New Delhi, Bangalore/Bengaluru',
#  'Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Mumbai, Bangalore/Bengaluru',
#  'Chennai, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Kolkata, Hyderabad/Secunderabad, Pune, Ahmedabad, Chennai, Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Pune, Bangalore/Bengaluru, Mumbai (All Areas)',
#  'New Delhi, Bangalore/Bengaluru',
#  'Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Mumbai, Bangalore/Bengaluru',
#  'Chennai, Bangalore/Bengaluru']

# %%
import pandas as pd
naukri=pd.DataFrame({})
naukri['title']=titles[0:20]
naukri['company']=company[0:20]
naukri['location']=job_location[0:20]
naukri['skill']=skill[0:20]
naukri
# Out:
#                                                 title  \
# 0                                        Data Analyst
# 1   Hiring Data Analysts For E commerce Platform |...
# 2                 Assistant Manager II - Data Analyst
# 3                                        Data Analyst
# 4                                        Data Analyst
# 5   DA - Urgent Opening For Data Analyst BFSI Doma...
# 6                                        Data Analyst
# 7                                        Data Analyst
# 8                                        Data Analyst
# 9                                        Data Analyst
# 10                                       Data Analyst
# 11                                       Data Analyst
# 12                      Data Analyst - Work from Home
# 13   Data Analyst Scada Systems & Database Management
# 14  Sybase SQL with Post trade/ settlement Data An...
# 15     Senior/Regular Business Analyst / Data Analyst
# 16                                       Data Analyst
# 17                            Hiring For Data Analyst
# 18            Business Data Analyst - MIS & Reporting
# 19                  Data Analyst / Business Analyst -
#
#                                     company  \
# 0   GlaxoSmithKline Pharmaceuticals Limited
# 1          Allegis Services India Pvt. Ltd.
# 2         Flipkart Internet Private Limited
# 3       Shell India Markets Private Limited
# 4                         Applied Materials
# 5            Tata Consultancy Services Ltd.
# 6       Shell India Markets Private Limited
# 7                  Myntra Designs Pvt. Ltd.
# 8                  Myntra Designs Pvt. Ltd.
# 9                  Myntra Designs Pvt. Ltd.
# 10                 Myntra Designs Pvt. Ltd.
# 11                 Myntra Designs Pvt. Ltd.
# 12  POWER STORES E COMMERCE PRIVATE LIMITED
# 13                          SmartHelio Sarl
# 14         Larsen & Toubro Infotech Limited
# 15                                   Luxoft
# 16                   IBM India Pvt. Limited
# 17        Flipkart Internet Private Limited
# 18                         INTERTRUST GROUP
# 19     LatentView Analytics Private Limited
#
#                                              location  \
# 0                                 Bangalore/Bengaluru
# 1                                 Bangalore/Bengaluru
# 2                                 Bangalore/Bengaluru
# 3                                 Bangalore/Bengaluru
# 4                                 Bangalore/Bengaluru
# 5   Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...
# 6                                 Bangalore/Bengaluru
# 7                                 Bangalore/Bengaluru
# 8                                 Bangalore/Bengaluru
# 9                                 Bangalore/Bengaluru
# 10                                Bangalore/Bengaluru
# 11                                Bangalore/Bengaluru
# 12      Pune, Bangalore/Bengaluru, Mumbai (All Areas)
# 13                     New Delhi, Bangalore/Bengaluru
# 14  Mumbai, Hyderabad/Secunderabad, Pune, Chennai,...
# 15                                Bangalore/Bengaluru
# 16                                Bangalore/Bengaluru
# 17                                Bangalore/Bengaluru
# 18                        Mumbai, Bangalore/Bengaluru
# 19                       Chennai, Bangalore/Bengaluru
#
#                                                 skill
# 0   Condition\nProduct Development\nR\nData Qualit...
# 1   Hive\nExcel\nData Analysis\nData Modeling\nDat...
# 2   R\nPower BI\nAccounting\nArtificial Intelligen...
# 3   Data Validation\nAzure Data Lake Store\nAzure ...
# 4   Real Time Analysis\nData Management\nData Anal...
# 5   Banking\nData Collection\nData Quality\nLoan O...
# 6   Data Validation\nExcel\nData Management\nCondi...
# 7   R\nExcel\nData Analysis\nTableau\nData Analyti...
# 8   R\nExcel\nData Analysis\nBusiness Insights\nTa...
# 9   Excel\nData Engineering\nData Analysis\nBusine...
# 10  R\nExcel\nData Analysis\nBusiness Insights\nTa...
# 11  R\nExcel\nData visualization\nData Analysis\nB...
# 12  Data Analysis\nCollection Management\nExcel\nP...
# 13  Database\nMPLS\nSCADA\nIT Skills\nMachine Lear...
# 14  Unix\nSybase SQL\nCapital markets\nJava\nIT Sk...
# 15  analytics\nAgile Methodology\nRetail\nData val...
# 16  Business Intelligence\nData Reconciliation\nSc...
# 17  Pivot Table\nSUMIF\nR\nVBA\nVLOOKUP\nTableau\n...
# 18  Power Bi\nSQL Server\nTableau\nSpotfire\nMS Vi...
# 19  Predictive Modeling\nData analyst\nBusiness An...
